# %% [markdown]
# # Visualizing orbital swath data
#
# 1. Try to identify the unique orbits using CMR API
# 2. Do a granule query to show the granule footprints for a single orbit in a bounding box
# 3. Plot those along with the tile layer
